# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from maturity import *
# Out:
# WARNING: Fixed weights in dimension (3) with absolute delta of 0.02
# WARNING: Fixed weights in dimension (5) with absolute delta of 0.03
# WARNING: Fixed weights in dimension (6) with absolute delta of -0.02
# WARNING: Fixed weights in dimension (top level) with absolute delta of -0.02

# %%
df = pd.read_csv("./data/results-survey413141.csv")
validate_columns(df)

sampled_answers = sample_data(1000)
sampled_answers = get_scores(sampled_answers)

# %%
maturity_scores = sampled_answers["Maturity_Score"]
maturity_scores.min(), maturity_scores.max()
# Out:
# (2.0826118743434305, 4.133394217602142)
